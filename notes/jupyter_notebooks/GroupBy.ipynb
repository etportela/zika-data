# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lista_dados_sage.csv',sep=';')

# %%
import datetime

# %%
df.head()
# Out:
#      ibge  uf        cidade  n_semana  n_ano  total_acumulado  \
# 0  120001  AC    Acrelândia         6   2016                0
# 1  120005  AC  Assis Brasil         6   2016                0
# 2  120010  AC     Brasiléia         6   2016                0
# 3  120010  AC     Brasiléia        37   2016                1
# 4  120010  AC     Brasiléia        38   2016                1
#
#    total_investigacao  total_confirmado  total_descartado  \
# 0                   0                 0                 0
# 1                   0                 0                 0
# 2                   0                 0                 0
# 3                   1                 0                 0
# 4                   1                 0                 0
#
#    total_obito_notificado  total_obito_investigado  total_obito_confirmado  \
# 0                       0                        0                       0
# 1                       0                        0                       0
# ...

# %%
df['LastDayWeek'] = pd.to_datetime((df['n_ano']).astype(str) + (df['n_semana']-1).astype(str) + "6", format="%Y%U%w")

# %%
df
# Out:
#          ibge  uf           cidade  n_semana  n_ano  total_acumulado  \
# 0      120001  AC       Acrelândia         6   2016                0
# 1      120005  AC     Assis Brasil         6   2016                0
# 2      120010  AC        Brasiléia         6   2016                0
# 3      120010  AC        Brasiléia        37   2016                1
# 4      120010  AC        Brasiléia        38   2016                1
# 5      120010  AC        Brasiléia        39   2016                1
# 6      120010  AC        Brasiléia        40   2016                1
# 7      120010  AC        Brasiléia        41   2016                1
# 8      120010  AC        Brasiléia        42   2016                1
# 9      120010  AC        Brasiléia        43   2016                1
# 10     120010  AC        Brasiléia        44   2016                1
# 11     120010  AC        Brasiléia        45   2016                1
# 12     120010  AC        Brasiléia        46   2016                1
# ...

# %%
type('LastDayWeek')
# Out:
# str

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=67243, step=1)

# %%
df.resample('M').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7a92209e47da> in <module>()
# ----> 1 df.resample('M').sum()
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    7106                      axis=axis, kind=kind, loffset=loffset,
#    7107                      convention=convention,
# -> 7108                      base=base, key=on, level=level)
#    7109         return _maybe_process_deprecations(r,
#    7110                                            how=how,
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1146     """ create a TimeGrouper and return our resampler """
#    1147     tg = TimeGrouper(**kwds)
# ...

# %%
df.groupby('LastDayWeek').resample('M').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f4424d091980> in <module>()
# ----> 1 df.groupby('LastDayWeek').resample('M').sum()
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\groupby\groupby.py in resample(self, rule, *args, **kwargs)
#    1500         """
#    1501         from pandas.core.resample import get_resampler_for_grouping
# -> 1502         return get_resampler_for_grouping(self, rule, *args, **kwargs)
#    1503
#    1504     @Substitution(name='groupby')
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\resample.py in get_resampler_for_grouping(groupby, rule, how, fill_method, limit, kind, **kwargs)
#    1160
#    1161     tg = TimeGrouper(freq=rule, **kwargs)
# -> 1162     resampler = tg._get_resampler(groupby.obj, kind=kind)
# ...

# %%
len(df1.groups)
# Out:
# 2179

# %%
df.count()
# Out:
# ibge                       67243
# uf                         67243
# cidade                     67243
# n_semana                   67243
# n_ano                      67243
# total_acumulado            67243
# total_investigacao         67243
# total_confirmado           67243
# total_descartado           67243
# total_obito_notificado     67243
# total_obito_investigado    67243
# total_obito_confirmado     67243
# total_obito_descartado     67243
# LastDayWeek                67243
# dtype: int64

# %%
ordena_cidades = df1.size()

# %%
ordena_cidades
# Out:
# cidade
# Abadiânia                 44
# Abaetetuba                44
# Abaeté                     3
# Abaré                     18
# Abaíra                     1
# Abreu e Lima              44
# Acajutiba                 41
# Acarape                   44
# Acaraú                    44
# Acari                      1
# Acará                      7
# Acrelândia                 1
# Adustina                   1
# Afogados da Ingazeira     44
# Afonso Bezerra            38
# Afonso Cláudio            17
# Afrânio                   40
# Agrestina                 44
# Aguanil                   22
# Aguiar                    44
# Aguiarnópolis             39
# Aiquara                    1
# Alagoa Grande             16
# Alagoa Nova               44
# Alagoinha                 75
# Alagoinhas                44
# Alcantil                  44
# Alcobaça                   1
# Alcântara                 42
# Alcântaras                39
#                         ...
# Votuporanga               44
# ...

# %%
ordena_cidades.sort_values()
# Out:
# cidade
# Lajes Pintadas               1
# Jaborandi                    1
# Jacaraci                     1
# Jacaré dos Homens            1
# Jacundá                      1
# Jacuípe                      1
# Janaúba                      1
# Jaramataia                   1
# Jardim de Angicos            1
# Ivoti                        1
# Jardim do Seridó             1
# Jericó                       1
# Jiquiriçá                    1
# Jitaúna                      1
# José da Penha                1
# João Dias                    1
# Juarez Távora                1
# Jucuruçu                     1
# Jussari                      1
# Jequiá da Praia              1
# Ivinhema                     1
# Iuiú                         1
# Ituberá                      1
# Iraquara                     1
# Itabi                        1
# Itaguaçu da Bahia            1
# Itaju do Colônia             1
# Italva                       1
# Itamaraju                    1
# Itamari                      1
# ...

# %%
df
# Out:
#          ibge  uf           cidade  n_semana  n_ano  total_acumulado  \
# 0      120001  AC       Acrelândia         6   2016                0
# 1      120005  AC     Assis Brasil         6   2016                0
# 2      120010  AC        Brasiléia         6   2016                0
# 3      120010  AC        Brasiléia        37   2016                1
# 4      120010  AC        Brasiléia        38   2016                1
# 5      120010  AC        Brasiléia        39   2016                1
# 6      120010  AC        Brasiléia        40   2016                1
# 7      120010  AC        Brasiléia        41   2016                1
# 8      120010  AC        Brasiléia        42   2016                1
# 9      120010  AC        Brasiléia        43   2016                1
# 10     120010  AC        Brasiléia        44   2016                1
# 11     120010  AC        Brasiléia        45   2016                1
# 12     120010  AC        Brasiléia        46   2016                1
# ...

# %%
df['LastDayWeek'] = pd.to_datetime(df['LastDayWeek'])

# %%
type(df['LastDayWeek'])
# Out:
# pandas.core.series.Series

# %%
df['mes'] = df["LastDayWeek"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))

# %%
df.resample('M').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7a92209e47da> in <module>()
# ----> 1 df.resample('M').sum()
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    7106                      axis=axis, kind=kind, loffset=loffset,
#    7107                      convention=convention,
# -> 7108                      base=base, key=on, level=level)
#    7109         return _maybe_process_deprecations(r,
#    7110                                            how=how,
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1146     """ create a TimeGrouper and return our resampler """
#    1147     tg = TimeGrouper(**kwds)
# ...

# %%
df['LastDayWeek'] = pd.to_datetime(df['LastDayWeek'], errors='coerce')

# %%
df.resample('M').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-7a92209e47da> in <module>()
# ----> 1 df.resample('M').sum()
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    7106                      axis=axis, kind=kind, loffset=loffset,
#    7107                      convention=convention,
# -> 7108                      base=base, key=on, level=level)
#    7109         return _maybe_process_deprecations(r,
#    7110                                            how=how,
#
# c:\users\marcelo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1146     """ create a TimeGrouper and return our resampler """
#    1147     tg = TimeGrouper(**kwds)
# ...
