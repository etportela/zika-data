# %%
import pandas as pd

# %%
import glob

# %%
dados[0].columns.values[0]
# Out:
# 'no'

# %%
path = 'C:\\mbafiabigdatat8\\zika-data\\data\\parsed\\brazil\\*.csv'
files = glob.glob(path)
dados_estados = list()
dados_resumo = list()

# %%
# Out:
# []

# %%
for name in files:
    pd1 = pd.read_csv(name)
    if pd1.columns.values[0] == 'no':
        dados_estados.append(pd1) 
    else:
        dados_resumo.append(pd1)

# %%
dados_resumo
# Out:
# [                 state  microcephaly_indicative_of_infection  \
#  0                Bahia                                    35
#  1                Ceará                                     3
#  2              Paraíba                                    29
#  3           Pernambuco                                   138
#  4  Rio Grande do Norte                                    58
#  5         Minas Gerais                                     0
#  6    Rio Grande do Sul                                     1
#
#     microcephaly_zika_positive total
#  0                           0    35
#  1                           1     4
#  2                           2    31
#  3                           0   138
#  4                           2    60
#  5                           1     1
#  6                           0    --  ]

# %%
data = pd.read_csv("C:\\mbafiabigdatat8\\zika-data\\data\\parsed\\brazil\\brazil-microcephaly-2016-01-23-table-1.csv")

# %%
data
# Out:
#     no                state cases_under_investigation cases_confirmed  \
# 0    1              Alagoas                       158               0
# 1    2                Bahia                       471              35
# 2    3                Ceará                       218               4
# 3    4             Maranhão                       119               0
# 4    5              Paraíba                       497              31
# 5    6           Pernambuco                      1125             138
# 6    7                Piauí                        91               0
# 7    8  Rio Grande do Norte                       133              60
# 8    9              Sergipe                       172               0
# 9   10       Espírito Santo                        52               0
# 10  11         Minas Gerais                         8               1
# 11  12       Rio de Janeiro                       122               0
# 12  13            São Paulo                        18               0
# 13  14                 Acre             Sem registros   Sem registros
# 14  15                Amapá             Sem registros   Sem registros
# 15  16             Amazonas             Sem registros   Sem registros
# 16  17                 Pará                         6               0
# 17  18             Rondônia                         1               0
# 18  19              Roraima                         5               0
# 19  20            Tocantins                        70               0
# 20  21     Distrito Federal                         5               0
# 21  22                Goiás                        62               0
# 22  23          Mato Grosso                       110               0
# 23  24   Mato Grosso do Sul                         3               0
# 24  25               Paraná                         2               0
# 25  26       Santa Catarina                         0               0
# 26  27    Rio Grande do Sul                         0               1
#
#    cases_discarded cases_reported_total
# 0                0                  158
# 1               27                  533
# 2                7                  229
# 3               15                  134
# 4              181                  709
# 5              110                 1373
# 6                0                   91
# 7               15                  208
# 8                0                  172
# 9                0                   52
# 10              39                   48
# 11               0                  122
# 12               0                   18
# 13   Sem registros       Sem registros
# 14   Sem registros       Sem registros
# 15   Sem registros       Sem registros
# 16               0                    6
# 17               0                    1
# 18               0                    5
# 19              12                   82
# 20               9                   14
# 21               0                   62
# 22              37                  147
# 23               1                    4
# 24               8                   10
# 25               1                    1
# 26               0                    1
