# %%
import pandas as pd

# %%
# Assign spreadsheet filename to `file`
file = 'C:\\Users\\BIG DATA T8\\Downloads\\atlas2013_dadosbrutos_pt.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# %%
xl.parse(sheet_name=0).to_csv(index=False, path_or_buf ='C:\\Users\\BIG DATA T8\\Downloads\\Indice.csv')

# %%
colunas = ['ANO',
    'UF',
    'Codmun6',
    'Codmun7',
    'Município',
    'T_AGUA',
    'T_BANAGUA',
    'T_DENS',
    'T_LIXO',
    'T_LUZ',
    'AGUA_ESGOTO']

pd_dados = xl.parse(sheet_name=1)

# %%
# Out:
#         ANO  UF  Codmun6  Codmun7                   Município  ESPVIDA  \
# 0      1991  11   110001  1100015       ALTA FLORESTA D'OESTE    62.01
# 1      1991  11   110002  1100023                   ARIQUEMES    66.02
# 2      1991  11   110003  1100031                      CABIXI    63.16
# 3      1991  11   110004  1100049                      CACOAL    65.03
# 4      1991  11   110005  1100056                  CEREJEIRAS    62.73
# 5      1991  11   110006  1100064           COLORADO DO OESTE    64.46
# 6      1991  11   110007  1100072                  CORUMBIARA    59.32
# 7      1991  11   110008  1100080               COSTA MARQUES    62.76
# 8      1991  11   110009  1100098             ESPIGÃO D'OESTE    64.18
# 9      1991  11   110010  1100106               GUAJARÁ-MIRIM    64.71
# 10     1991  11   110011  1100114                        JARU    64.46
# 11     1991  11   110012  1100122                   JI-PARANÁ    64.51
# ...

# %%
pd_dados[colunas]
# Out:
#         ANO  UF  Codmun6  Codmun7                   Município  T_AGUA  \
# 0      1991  11   110001  1100015       ALTA FLORESTA D'OESTE   21.92
# 1      1991  11   110002  1100023                   ARIQUEMES   53.30
# 2      1991  11   110003  1100031                      CABIXI   11.82
# 3      1991  11   110004  1100049                      CACOAL   52.77
# 4      1991  11   110005  1100056                  CEREJEIRAS   44.47
# 5      1991  11   110006  1100064           COLORADO DO OESTE   36.09
# 6      1991  11   110007  1100072                  CORUMBIARA    7.17
# 7      1991  11   110008  1100080               COSTA MARQUES   28.27
# 8      1991  11   110009  1100098             ESPIGÃO D'OESTE   39.10
# 9      1991  11   110010  1100106               GUAJARÁ-MIRIM   51.93
# 10     1991  11   110011  1100114                        JARU   30.94
# 11     1991  11   110012  1100122                   JI-PARANÁ   54.31
# ...

# %%
#!pip install xlrd
# Out:
# pandas.io.excel.ExcelFile

# %%
file_name_ori = 'C:\\Users\\BIG DATA T8\\Downloads\\IBGE_hist'
outfile = open(file_name_ori,'wb')

file_dict = { 'IBGE_Hist': xl }

pickle.dump(file_dict,outfile)
outfile.close()
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-84-e8c9c9dce9c2> in <module>()
#       4 file_dict = { 'IBGE_Hist': xl }
#       5
# ----> 6 pickle.dump(file_dict,outfile)
#       7 outfile.close()
#
# PicklingError: Can't pickle <function <lambda> at 0x0000029560E3C048>: attribute lookup <lambda> on jupyter_client.session failed

# %%
import pickle

file_name = 'C:\\Users\\BIG DATA T8\\Downloads\\IBGE_Mun'
outfile = open(file_name,'wb')

# %%
file_dict = { 'IBGE_Mun': pd_dados[colunas] }

# %%
pickle.dump(file_dict,outfile)
outfile.close()

# %%
infile = open(file_name,'rb')
new_dict = pickle.load(infile)
infile.close()

# %%
new_dict
# Out:
# {'IBGE_Mun':         ANO  UF  Codmun6  Codmun7                   Município  T_AGUA  \
#  0      1991  11   110001  1100015       ALTA FLORESTA D'OESTE   21.92
#  1      1991  11   110002  1100023                   ARIQUEMES   53.30
#  2      1991  11   110003  1100031                      CABIXI   11.82
#  3      1991  11   110004  1100049                      CACOAL   52.77
#  4      1991  11   110005  1100056                  CEREJEIRAS   44.47
#  5      1991  11   110006  1100064           COLORADO DO OESTE   36.09
#  6      1991  11   110007  1100072                  CORUMBIARA    7.17
#  7      1991  11   110008  1100080               COSTA MARQUES   28.27
#  8      1991  11   110009  1100098             ESPIGÃO D'OESTE   39.10
#  9      1991  11   110010  1100106               GUAJARÁ-MIRIM   51.93
#  10     1991  11   110011  1100114                        JARU   30.94
#  11     1991  11   110012  1100122                   JI-PARANÁ   54.31
# ...

# %%
ctrl + Enter
Alt + Enter
Shift + Enter
Esc
Esc , dd
Esc , k
Esc , y
Esc , m
Esc , a
Esc , b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-f57e26bdd7ab> in <module>()
# ----> 1 ctrl + Enter
#       2 Alt + Enter
#
# NameError: name 'ctrl' is not defined

# %%
asdf

# %% [markdown]
# sfbw

# %%
pd1 = xl.parse(sheet_name=0)

# %%
serie = pd1['SIGLA']

# %%
serie
# Out:
# 0                     UF
# 1                    UFN
# 2                CODMUN6
# 3                CODMUN7
# 4                NOMEMUN
# 5                ESPVIDA
# 6                 FECTOT
# 7                  MORT1
# 8                  MORT5
# 9                 RAZDEP
# 10               SOBRE40
# 11               SOBRE60
# 12                 T_ENV
# 13          E_ANOSESTUDO
# 14          T_ANALF11A14
# 15          T_ANALF15A17
# 16            T_ANALF15M
# 17          T_ANALF18A24
# 18            T_ANALF18M
# 19          T_ANALF25A29
# 20            T_ANALF25M
# 21     T_ATRASO_0_BASICO
# 22       T_ATRASO_0_FUND
# 23        T_ATRASO_0_MED
# 24     T_ATRASO_1_BASICO
# 25       T_ATRASO_1_FUND
# 26        T_ATRASO_1_MED
# 27     T_ATRASO_2_BASICO
# 28       T_ATRASO_2_FUND
# 29        T_ATRASO_2_MED
#              ...
# 207               PESO18
# 208             Peso1820
# 209             Peso1824
# 210             Peso1921
# 211               PESO25
# 212                PESO4
# ...
